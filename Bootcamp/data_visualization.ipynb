# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Matplotlib

# %%
plt.plot(range(14),[i**2 for i in range(14)],"r*")
plt.xlabel("numbers")
plt.ylabel("square of numbers")
plt.title("plt.plot")
plt.show()

# %%
# Plot fonksiyonuna tek figure üzerine birden fazla grafik cizdirebiliriz
arr = np.arange(0,10,0.5)
plt.plot(arr,arr,"r*",arr,arr**2,"b*",arr,arr**3,"g*",markersize=7)
#markersize -> işaretlerin büyüklüğü
#linewidth -> çizgi kalınlığı
plt.show()

# %%
data = {"a": np.arange(50),
        "b": np.random.randint(0,100,50),
        "c": np.random.randn(50)}
data["d"] = data["a"] + (10 * np.abs(np.random.randn(50)))
data["c"] = np.abs(data["c"]) * 100

plt.scatter(data=data,x="a",y="b",c="c",s="d")
plt.show()

# %%
# data
players = ["player1","player2","player3","player4"]
points = np.random.randint(0,100,4)

# subplot -> Birden fazla grafiği bir arada cizmek icin kullanilir
plt.figure(figsize=(9,3))

# graph 1
plt.subplot(131) # 131 -> 1 satir 3 sütun olan figürün 1. grafiği
plt.bar(players,points,color="orange")

# graph2
plt.subplot(132) # 132 -> 1 satır 3 sütun olan figürün 2. graifiği
plt.scatter(players,points)

#graph3
plt.subplot(133) # 133 -> 1 satir 3 sütun olan figürün 3. grafiği
plt.plot(players,points,"r--")

plt.show()

# %%
#histogram
mu1 = 100 # ortalama
sigma1 = 15 # standart sapma
x = mu1 + (sigma1 * np.random.randn(10000)) # normal dağılım olan bir veri kümesi

mu2 = 110 
sigma2 = 10
y = mu2 + (sigma2 * np.random.randn(10000))

plt.figure(figsize=(9,5))
plt.hist(x,bins=100,density=1,facecolor="g",alpha=0.25) # bins -> histogramın aralık sayisi
plt.hist(y,bins=100,density=1,facecolor="b",alpha=0.25)
plt.xlabel("Data")
plt.ylabel("Probabilities")
plt.title(r"$\mu_1=100,\ \mu_2=110$") # Mü, sigma gibi işaretleri 2 $ işareti arasinda yazdirabiliyoruz
plt.grid(True,alpha=0.4) # Grid oluşturuldu
plt.annotate('Top of the gaussian curve',xy=(110,0.04),xytext=(130,0.045),
            arrowprops=dict(facecolor='black',shrink=1)) # Ok işareti ile histogramın tepe noktası işaret edildi
plt.text(60,0.020,r"$\mu_1=100,\ \sigma_1=15$") 
plt.text(120,0.030,r"$\mu_1=110,\ \sigma_2=10$")
plt.axis([40,160,0,0.05])
plt.show()

# %%
# Scaling
# Bazı durumlarda sayilar cok büyük olduğu için grafik uzerinde anlasılamaz olabilir
# Bu sorunu gidermek icin logaritma fonksiyonu ile y eksenindeki degerler scale edilerek algılanabilir hale getirildi
x = np.arange(0,10,0.01)
y = np.exp(x)

plt.figure(figsize=(9,3))

plt.subplot(121)
plt.plot(x,y)
plt.yscale("linear")
plt.title("Linear scaling")
plt.grid(True,alpha=0.4)

plt.subplot(122)
plt.plot(x,y)
plt.yscale("log")
plt.title("Logaritmic scaling")
plt.grid(True,alpha=0.4)

plt.show()

# %% [markdown]
# # Seaborn

# %%
# import data
df = pd.read_csv("../datasets/clean_athlete_events.csv")
df.head()
# Out:
#                        name gender   age  height  weight            team  noc  \
# 0      Edgar Lindenau Aabye      M  34.0  182.48   95.62  Denmark/Sweden  DEN
# 1      Arvo Ossian Aaltonen      M  30.0  182.01   76.69         Finland  FIN
# 2      Arvo Ossian Aaltonen      M  30.0  177.00   75.00         Finland  FIN
# 3  Juhamatti Tapio Aaltonen      M  28.0  184.00   85.00         Finland  FIN
# 4   Paavo Johannes Aaltonen      M  28.0  175.00   64.00         Finland  FIN
#
#    year  season       city       sport  \
# 0  1900  Summer      Paris  Tug-Of-War
# 1  1920  Summer  Antwerpen    Swimming
# 2  1920  Summer  Antwerpen    Swimming
# 3  2014  Winter      Sochi  Ice Hockey
# 4  1948  Summer     London  Gymnastics
#
#                                     event   medal
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# 3             Ice Hockey Men's Ice Hockey  Bronze
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39783 entries, 0 to 39782
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    39783 non-null  object
#  1   gender  39783 non-null  object
#  2   age     39783 non-null  float64
#  3   height  39783 non-null  float64
#  4   weight  39783 non-null  float64
#  5   team    39783 non-null  object
#  6   noc     39783 non-null  object
#  7   year    39783 non-null  int64
#  8   season  39783 non-null  object
#  9   city    39783 non-null  object
#  10  sport   39783 non-null  object
#  11  event   39783 non-null  object
#  12  medal   39783 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Scatter Plot

# %%
def drawScatterPlot():
    sns.scatterplot(x="height",y="weight",data=df)
    plt.title("Relationship between height and weight")
    sns.set_style(style="white")
    plt.show()
drawScatterPlot()

# %%
sns.set_style(style="darkgrid")
drawScatterPlot()

# %%
sns.set_style(style="whitegrid")
drawScatterPlot()

# %% [markdown]
# ## Scatter Plot - Categorical

# %%
# Kategorik veriler hue parametresi ile istenilen sütundaki farklı degerler renklendirilerek birbirinden ayrıldı
sns.scatterplot(x="height",y="weight",data=df,hue="medal")
plt.title("Height and weight scatter plot by medals")
plt.grid(True,alpha=0.2)
plt.show()

# %%
sns.scatterplot(x="height",y="weight",data=df,hue="gender")
plt.title("Height and weight scatter plot by gender")
plt.grid(True,alpha=0.4)
plt.show()

# %%
# Style parametresi ile grafiğe 4. boyutu kazandırıyoruz
# Style parametresi ile farklı madalya alan sporcuları farklı sekillerde gosteriyoruz
sns.scatterplot(x="height",y="weight",data=df,hue="gender",style="medal")
plt.title("Height and weight scatter plot by gender")
plt.grid(True,alpha=0.4)
plt.show()

# %%
# Size parametresi ile 5. boyutlu grafik olusturuyoruz
sns.scatterplot(x="height",y="weight",data=df,hue="gender",style="medal",size="age")
plt.title("Height and weight scatter plot by gender")
plt.grid(True,alpha=0.4)
plt.show()

# %% [markdown]
#  ## Scatter Plot - Linear Regression

# %%
sns.regplot(x="height",y="weight",data=df,marker="+",scatter_kws={'alpha':0.2})
plt.grid(True,alpha=0.4)
plt.show()

# %% [markdown]
# ## Color Palette

# %%
# Renk paletleri için seaborn.pydata.org sitesinden color_palette kısmına bakılabilir
sns.scatterplot(x="height",y="weight",data=df,hue='medal',palette="Set1")
plt.show()

# %%
sns.scatterplot(x="height",y="weight",data=df,hue='medal',palette="Set2")
plt.show()

# %%
sns.scatterplot(x="height",y="weight",data=df,hue='medal',palette="Set3")
plt.show()

# %%
sns.scatterplot(x="height",y="weight",data=df,hue='medal',palette="Reds")
plt.show()

# %%
sns.scatterplot(x="height",y="weight",data=df,hue='medal',palette="flare")
plt.show()

# %% [markdown]
# ## Lineplot

# %%
sns.lineplot(x="height",y="weight",data=df)
plt.grid(True,alpha=0.4)
plt.show()

# %%
sns.lineplot(x="height",y="weight",data=df,hue="gender")
plt.grid(True,alpha=0.4)
plt.show()

# %% [markdown]
# ## Histogram

# %%
sns.displot(data=df,x="weight")
plt.grid(True,alpha=0.4)
plt.show()

# %%
sns.displot(data=df,x="weight",hue="gender")
plt.grid(True,alpha=0.4)
plt.show()

# %%
sns.displot(data=df,x="weight",col="gender")
plt.grid(True,alpha=0.4)
plt.show()

# %% [markdown]
# ## Two dimensional Histogrma

# %%
sns.displot(data=df,x="weight",y="height",kind="kde")
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Height-Weight Histogram")
plt.show()

# %%
sns.displot(data=df,x="weight",y="height",kind="kde",hue="gender")
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Height-Weight Histogram by gender")
plt.show()

# %%
sns.kdeplot(data=df,x="weight",y="height",hue="gender",fill=True)
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Height-Weight Histogram by gender")
plt.show()

# %% [markdown]
# ## Barplot

# %%
sns.barplot(data=df,x="medal",y="height",palette="flare")
plt.show()

# %%
sns.barplot(data=df,x="medal",y="height",palette="Set3",hue="gender")
plt.show()

# %%
sns.catplot(data=df,x="medal",y="age",hue="gender",col="season",kind="bar",height=4,aspect=1,palette="rocket")
# aspect -> en boy oranı
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x="season",y="height",data=df)
plt.show()

# %%
sns.boxplot(x="season",y="height",hue="gender",data=df,palette="rocket")
plt.show()

# %%
temp_df = df.loc[:,["age","weight","height"]]
sns.boxplot(data=temp_df,orient="h",palette="Set3")
plt.show()

# %%
sns.set_palette("Set2")
sns.catplot(data=df,x="season",y="height",hue="gender",col="medal",kind="box",height=4,aspect=0.7)
plt.show()

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(data=df.corr(),annot=True,linewidths=0.5,fmt=".3f")
plt.show()
#annot = korelasyon degerlerini True gösterir False kapatir
#linewidths = Kutular arası mesafe
#fmt = Degerlerin ondalık basamak sayiları

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x="season",y="height",data=df)
plt.show()

# %%
sns.violinplot(x="season",y="height",data=df,hue="gender")
plt.show()

# %%
sns.violinplot(x="season",y="height",data=df,hue="gender",split=True)
plt.show()

# %%
sns.catplot(data=df,kind="violin",x="season",y="height",hue="gender",col="medal")
plt.show()

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(data=df,x="weight",y="height",hue="season",kind="kde")
plt.show()

# %%
p = sns.JointGrid(data=df,x="weight",y="height")
p.plot_joint(sns.histplot)
p.plot_marg
